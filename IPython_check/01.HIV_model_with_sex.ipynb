# %%
# %matplotlib inline

# Standard imports
import copy
import itertools

# Scientific computing imports
import numpy
import matplotlib.pyplot as plt
import networkx
import pandas
import seaborn; seaborn.set()

# Import widget methods
from IPython.html.widgets import *

# %%
class Person(object):
    """
    Person class, which encapsulates the entire behavior of a person.
    """
    
    def __init__(self, model, person_id, is_infected=False, is_Male = True, condom_budget=1.0, prob_hookup_hetero =0.5,
                 prob_hookup_homo = 0.05):
        """
        Constructor for Person class.  By default,
          * not infected
          * will always buy condoms
          * will hookup 50% of the time
          
        Note that we must "link" the Person to their "parent" Model object.
        """
        # Set model link and ID
        self.model = model
        self.person_id = person_id
        
        # Set Person parameters.
        self.is_infected = is_infected
        self.is_Male = is_Male
        self.condom_budget = condom_budget
        self.prob_hookup_hetero = prob_hookup_hetero
        self.prob_hookup_homo = prob_hookup_homo
        
    def decide_condom(self):
        """
        Decide if we will use a condom.
        """
        if self.condom_budget >= (self.model.condom_cost - self.model.condom_subsidy):
            return True
        else:
            return False
    
    
    def get_position(self):
        """
        Return position, calling through model.
        """
        return self.model.get_person_position(self.person_id)
    
    def get_neighbors(self):
        """
        Return neighbors, calling through model.
        """
        return self.model.get_person_neighbors(self.person_id, self.sex)
    

    def __repr__(self):
        '''
        Return string representation.
        '''
        skip_none = True
        repr_string = type(self).__name__ + " ["
        except_list = "model"

        elements = [e for e in dir(self) if str(e) not in except_list]
        for e in elements:
            # Make sure we only display "public" fields; skip anything private (_*), that is a method/function, or that is a module.
            if not e.startswith("_") and eval('type(self.{0}).__name__'.format(e)) not in ['DataFrame', 'function', 'method', 'builtin_function_or_method', 'module', 'instancemethod']:
                    value = eval("self." + e)
                    if value != None and skip_none == True:
                        repr_string += "{0}={1}, ".format(e, value)

        # Clean up trailing space and comma.
        return repr_string.strip(" ").strip(",") + "]"

# %%
class Model(object):
    """
    Model class, which encapsulates the entire behavior of a single "run" in our HIV ABM.
    """
    
    def __init__(self, grid_size, num_people, min_subsidy=0.0, max_subsidy=1.0,
                     min_condom_budget=0.0, max_condom_budget=2.0,
                     condom_cost=1.0, min_prob_hookup_hetero=0.0, max_prob_hookup_hetero=1.0,
                     min_prob_hookup_homo_f = 0.0, max_prob_hookup_homo_f = 1.0,
                     min_prob_hookup_homo_m = 0.0, max_prob_hookup_homo_m = 1.0,
                    prob_transmit_hetero=0.9, prob_transmit_homo_m = 0.95,
                    prob_transmit_homo_f = 0.85, prob_transmit_condom_hetero=0.1,
                    prob_transmit_condom_homo_m = 0.2, prob_transmit_condom_homo_f = 0.05):
        """
        Class constructor.
        """
        # Set our model parameters; this is long but simple!
        self.grid_size = grid_size
        self.num_people =  num_people
        self.min_subsidy = min_subsidy
        self.max_subsidy = max_subsidy
        self.min_condom_budget = min_condom_budget
        self.max_condom_budget = max_condom_budget
        self.condom_cost = condom_cost
        self.min_prob_hookup_hetero = min_prob_hookup_hetero
        self.max_prob_hookup_hetero = max_prob_hookup_hetero
        self.min_prob_hookup_homo_f = min_prob_hookup_homo_f
        self.max_prob_hookup_homo_f = max_prob_hookup_homo_f
        self.min_prob_hookup_homo_m = min_prob_hookup_homo_m
        self.max_prob_hookup_homo_m = max_prob_hookup_homo_m
        self.prob_transmit_hetero = prob_transmit_hetero
        self.prob_transmit_homo_m = prob_transmit_homo_m
        self.prob_transmit_homo_f = prob_transmit_homo_f
        self.prob_transmit_condom_hetero = prob_transmit_condom_hetero
        self.prob_transmit_condom_homo_m = prob_transmit_condom_homo_m
        self.prob_transmit_condom_homo_f = prob_transmit_condom_homo_f
        
        # Set our state variables
        self.t = 0
        self.space = numpy.array((0,0))
        self.condom_subsidy = 0.0
        self.people = []
        self.people_sexlist = []
        self.num_interactions = 0
        self.num_interactions_condoms = 0
        self.num_transmit_homo_f = 0
        self.num_transmit_homo_m = 0
        self.num_transmit_hetero = 0
        self.num_transmit_condom = 0
        self.num_transmit_non_condom = 0
        self.num_infected = 0
        
        # Setup our history variables.
        self.history_space = []
        self.history_space_infected = []
        self.history_interactions = []
        self.history_num_infected = []
        self.history_num_interactions = []
        self.history_num_interactions_condoms = []
        
        # Call our setup methods to initialize space, people, and institution.
        self.setup_space()
        self.setup_people()
        self.setup_institution()
        
    def setup_space(self):
        """
        Method to setup our space.
        """
        # Initialize a space with a NaN's
        self.space = numpy.full((self.grid_size, self.grid_size), numpy.nan)
    
    def setup_people(self):
        """
        Method to setup our space.
        """
        
        # First, begin by creating all agents without placing them.
        for i in xrange(self.num_people):
            if(numpy.random.random()<0.5):
                decide_Male = False
                prob_hookup_homo = numpy.random.uniform(self.min_prob_hookup_homo_f, self.max_prob_hookup_homo_f)
            else:
                decide_Male = True
                prob_hookup_homo = numpy.random.uniform(self.min_prob_hookup_homo_m, self.max_prob_hookup_homo_m)
            self.people.append(Person(model=self,
                                      person_id=i,
                                      is_infected=False, is_Male = decide_Male,
                                      condom_budget=numpy.random.uniform(self.min_condom_budget, self.max_condom_budget),
                                      prob_hookup_hetero=numpy.random.uniform(self.min_prob_hookup_hetero, self.max_prob_hookup_hetero),
                                       prob_hookup_homo = prob_hookup_homo))

            self.people_sexlist.append([i, self.people[i].is_Male])
        
        # Second, once created, place them into the space.
        for person in self.people:
            # Loop until unique
            is_occupied = True
            while is_occupied:
                # Sample location
                random_x = numpy.random.randint(0, self.grid_size)
                random_y = numpy.random.randint(0, self.grid_size)
                
                # Check if unique
                if numpy.isnan(self.space[random_x, random_y]):
                    is_occupied = False
                else:
                    is_occupied = True
            
            # Now place the person there by setting their ID.
            self.space[random_x, random_y] = person.person_id
            
        # Third, pick one person to be infected initially.
        random_infected = numpy.random.choice(range(self.num_people))
        self.people[random_infected].is_infected = True
        self.num_infected += 1

    def setup_institution(self):
        """
        Method to setup our space.
        """
        # Randomly sample a subsidy level
        self.condom_subsidy = numpy.random.uniform(self.min_subsidy, self.max_subsidy)
    
    def get_neighborhood(self, x, y, distance=1):
        """
        Get a Moore neighborhood of distance from (x, y).
        """
        neighbor_pos = [ ( x % self.grid_size, y % self.grid_size)
                                for x, y in itertools.product(xrange(x-distance, x+distance+1),
                                xrange(y-distance, y+distance+1))]
        return neighbor_pos
    
    def get_neighbors(self, x, y, distance=1):
        """
        Get any neighboring persons within distance from (x, y).
        """
        neighbor_pos = self.get_neighborhood(x, y, distance)
        neighbor_list = []
        for pos in neighbor_pos:
            # Skip identity
            if pos[0] == x and pos[1] == y:
                continue
                
            # Check if empty
            if not numpy.isnan(self.space[pos[0], pos[1]]):
                neighbor_list.append(self.people_sexlist[int(self.space[pos[0], pos[1]])])
        
        return neighbor_list
    
    def get_person_position(self, person_id):
        """
        Get the position of a person based on their ID.
        """
        # Find the value that matches our ID in self.space, then reshape to a 2-element list.
        return numpy.reshape(numpy.where(m.space == person_id), (1, 2))[0].tolist()

    def get_person_neighbors(self, person_id, distance=1):
        """
        Get the position of a person based on their ID.
        """
        # Find the value that matches our ID in self.space, then reshape to a 2-element list.
        x, y = self.get_person_position(person_id)
        return self.get_neighbors(x, y, distance)   
    
    def move_person(self, person_id, x, y):
        """
        Move a person to a new (x, y) location.
        """
        
        # Get original
        original_position = self.get_person_position(person_id)
        
        # Check target location
        if not numpy.isnan(self.space[x, y]):
            raise ValueError("Unable to move person {0} to ({1}, {2}) since occupied.".format(person_id, x, y))
        
        # Otherwise, move by emptying and setting.
        self.space[original_position[0], original_position[1]] = numpy.nan
        self.space[x, y] = person_id
    
    def step_move(self):
        """
        Model step move function, which handles moving agents randomly around.
        """
        
        # Get a random order for the agents.
        random_order = range(self.num_people)
        numpy.random.shuffle(random_order)
        
        # Iterate in random order.
        for i in random_order:
            # Get current position
            x, y = self.get_person_position(i)
            
            # Move our agent between -1, 0, +1 in each dimension
            x_new = (x + numpy.random.randint(-1, 2)) % self.grid_size
            y_new = (y + numpy.random.randint(-1, 2)) % self.grid_size
            
            # Try to move them
            try:
                self.move_person(i, x_new, y_new)
            except ValueError:
                # Occupied, so fail.
                pass
    
    def step_interact(self):
        """
        "Interact" the agents by seeing if they will hookup and spread.
        """
        
        # Get a random order for the agents.
        random_order = range(self.num_people)
        numpy.random.shuffle(random_order)
        
        # Track which pairs we've tested.  Don't want to "interact" them twice w/in one step.
        seen_pairs = []
        
        # Iterate in random order.
        for i in random_order:
            # Get neighbors
            neighbors = self.get_person_neighbors(i)
            
            # Iterate over neighbors
            for neighbor in neighbors:
                # Check if we've already seen.
                a = min(i, neighbor[0])
                b = max(i, neighbor[0])
                if (a, b) not in seen_pairs:
                    seen_pairs.append((a, b))
                else:
                    continue
                
                # Check if hookup if not seen.
                hookup_a = False
                hookup_b = False
                homo_flag = False
                
                # If they belong to the same sex
                if(self.people[a].is_Male == self.people[b].is_Male):
                    homo_flag = True
                    if(numpy.random.random() <= self.people[a].prob_hookup_homo):
                        hookup_a = True
                    if(numpy.random.random() <= self.people[b].prob_hookup_homo):
                        hookup_b = True
                else:
                    if(numpy.random.random() <= self.people[a].prob_hookup_hetero):
                        hookup_a = True
                    if(numpy.random.random() <= self.people[b].prob_hookup_hetero):
                        hookup_b = True
                
                if hookup_a and hookup_b:
                    # Hookup going to happen.  
                    self.num_interactions += 1
                    is_transmission = False                    
                    # Check now for condoms and use resulting rate.
                    if self.people[a].decide_condom() or self.people[b].decide_condom():
                        # Using a condom.
                        self.num_interactions_condoms += 1
                        use_condom = True
                        
                        if self.people[a].is_infected ^ self.people[b].is_infected:
                            if(homo_flag & self.people[a].is_Male):
                                is_transmission = numpy.random.random() <= self.prob_transmit_condom_homo_m
                                if(is_transmission):
                                    self.num_transmit_homo_m += 1
                            elif(homo_flag & (not self.people[a].is_Male)):
                                is_transmission = numpy.random.random() <= self.prob_transmit_condom_homo_f
                                if(is_transmission):
                                    self.num_transmit_homo_f += 1
                            else:
                                is_transmission = numpy.random.random() <= self.prob_transmit_condom_hetero
                                if(is_transmission):
                                    self.num_transmit_hetero += 1
                                    
                            if(is_transmission):
                                self.num_transmit_condom += 1
                        else:
                            is_transmission = False
                    else:
                        # Not using a condom.
                        use_condom = False
                        if self.people[a].is_infected ^ self.people[b].is_infected:
                            if(homo_flag & self.people[a].is_Male):
                                is_transmission = numpy.random.random() <= self.prob_transmit_homo_m
                                if(is_transmission):
                                    self.num_transmit_homo_m += 1
                            elif(homo_flag & (not self.people[a].is_Male)):
                                is_transmission = numpy.random.random() <= self.prob_transmit_homo_f
                                if(is_transmission):
                                    self.num_transmit_homo_f += 1
                            else:
                                is_transmission = numpy.random.random() <= self.prob_transmit_hetero
                                if(is_transmission):
                                    self.num_transmit_hetero += 1
                            if(is_transmission):
                                self.num_transmit_non_condom += 1
                        else:
                            is_transmission = False
                    
                    # Now infect.
                    self.history_interactions.append((self.t, a, b, use_condom, is_transmission))
                    if is_transmission:
                        self.people[a].is_infected = True
                        self.people[b].is_infected = True
    
    def get_num_infected(self):
        """
        Get the number of infected persons.
        """
        # Count
        infected = 0
        for person in self.people:
            if person.is_infected:
                infected += 1
                
        return infected
    
    def step(self):
        """
        Model step function.
        """
        
        # "Interact" agents.
        self.step_interact()
        
        # Move agents
        self.step_move()
        
        # Increment steps and track history.
        self.t += 1
        self.history_space.append(copy.deepcopy(self.space))
        self.history_space_infected.append(self.get_space_infected())
        self.num_infected = self.get_num_infected()
        self.history_num_infected.append(self.num_infected)
        self.history_num_interactions.append(self.num_interactions)
        self.history_num_interactions_condoms.append(self.num_interactions_condoms)

    def get_space_infected(self, t=None):
        """
        Return a projection of the space that shows which cells have an infected person.
        """
        if t == None:
            # Initialize empty
            infected_space = numpy.zeros_like(self.space)
            
            # Iterate over persons and set.
            for p in self.people:
                x, y = self.get_person_position(p.person_id)
                if p.is_infected:
                    infected_space[x, y] = +1
                else:
                    infected_space[x, y] = -1
            
            # Return
            return infected_space
        else:
            # Return historical step
            return self.history_space_infected[t]

    def __repr__(self):
        '''
        Return string representation.
        '''
        skip_none = True
        repr_string = type(self).__name__ + " ["

        elements = dir(self)
        for e in elements:
            # Make sure we only display "public" fields; skip anything private (_*), that is a method/function, or that is a module.
            e_type = eval('type(self.{0}).__name__'.format(e))
            if not e.startswith("_") and e_type not in ['DataFrame', 'function', 'method', 'builtin_function_or_method', 'module', 'instancemethod']:
                    value = eval("self." + e)
                    if value != None and skip_none == True:
                        if e_type in ['list', 'set', 'tuple']:
                            repr_string += "\n\n\t{0}={1},\n\n".format(e, value)
                        elif e_type in ['ndarray']:
                            repr_string += "\n\n\t{0}=\t\n{1},\n\n".format(e, value)
                        else:
                            repr_string += "{0}={1}, ".format(e, value)

        # Clean up trailing space and comma.
        return repr_string.strip(" ").strip(",") + "]"

# %%
# Create model and output
m = Model(grid_size=20, num_people=25, min_prob_hookup_hetero=0.0, max_prob_hookup_hetero=1.0,
          min_prob_hookup_homo_f = 0.0, max_prob_hookup_homo_f = 0.3,
          min_prob_hookup_homo_m = 0.0, max_prob_hookup_homo_m = 0.3,
          prob_transmit_hetero=0.7, prob_transmit_homo_m = 0.9,
          prob_transmit_homo_f = 0.6, prob_transmit_condom_hetero=0.1,
          prob_transmit_condom_homo_m = 0.2, prob_transmit_condom_homo_f = 0.05)
print(m)
# Out:
# Model [condom_cost=1.0, condom_subsidy=0.393428167941, grid_size=20,
#
# 	history_interactions=[],
#
#
#
# 	history_num_infected=[],
#
#
#
# 	history_num_interactions=[],
#
#
#
# 	history_num_interactions_condoms=[],
#
#
#
# 	history_space=[],
#
#
#
# 	history_space_infected=[],
#
# max_condom_budget=2.0, max_prob_hookup_hetero=1.0, max_prob_hookup_homo_f=0.3, max_prob_hookup_homo_m=0.3, max_subsidy=1.0, min_condom_budget=0.0, min_prob_hookup_hetero=0.0, min_prob_hookup_homo_f=0.0, min_prob_hookup_homo_m=0.0, min_subsidy=0.0, num_infected=1, num_interactions=0, num_interactions_condoms=0, num_people=25, num_transmit_condom=0, num_transmit_hetero=0, num_transmit_homo_f=0, num_transmit_homo_m=0, num_transmit_non_condom=0,
#
# 	people=[Person [condom_budget=0.654854301104, is_Male=False, is_infected=False, person_id=0, prob_hookup_hetero=0.391445861967, prob_hookup_homo=0.250524538767], Person [condom_budget=1.78678337711, is_Male=False, is_infected=False, person_id=1, prob_hookup_hetero=0.813194251332, prob_hookup_homo=0.0339283475935], Person [condom_budget=0.492870468481, is_Male=True, is_infected=False, person_id=2, prob_hookup_hetero=0.3122906332, prob_hookup_homo=0.265780707029], Person [condom_budget=1.37413940417, is_Male=True, is_infected=False, person_id=3, prob_hookup_hetero=0.658243439872, prob_hookup_homo=0.113687692081], Person [condom_budget=1.57639826084, is_Male=True, is_infected=False, person_id=4, prob_hookup_hetero=0.783582752695, prob_hookup_homo=0.167124110519], Person [condom_budget=1.56129720061, is_Male=True, is_infected=False, person_id=5, prob_hookup_hetero=0.681022780177, prob_hookup_homo=0.0948374601422], Person [condom_budget=1.18316630993, is_Male=False, is_infected=True, person_id=6, prob_hookup_hetero=0.280244127872, prob_hookup_homo=0.290190768429], Person [condom_budget=1.84992651428, is_Male=True, is_infected=False, person_id=7, prob_hookup_hetero=0.578896007411, prob_hookup_homo=0.252590820125], Person [condom_budget=0.928768551015, is_Male=True, is_infected=False, person_id=8, prob_hookup_hetero=0.436654225597, prob_hookup_homo=0.208427521635], Person [condom_budget=0.43247332193, is_Male=True, is_infected=False, person_id=9, prob_hookup_hetero=0.223455268419, prob_hookup_homo=0.163728298018], Person [condom_budget=0.0726911416792, is_Male=True, is_infected=False, person_id=10, prob_hookup_hetero=0.891157261165, prob_hookup_homo=0.136726408334], Person [condom_budget=0.839660841173, is_Male=True, is_infected=False, person_id=11, prob_hookup_hetero=0.13040514373, prob_hookup_homo=0.144916078693], Person [condom_budget=0.103899932571, is_Male=False, is_infected=False, person_id=12, prob_hookup_hetero=0.898361752768, prob_hookup_homo=0.0831351384858], Person [condom_budget=1.66203852022, is_Male=True, is_infected=False, person_id=13, prob_hookup_hetero=0.99823330892, prob_hookup_homo=0.0955681333297], Person [condom_budget=0.300592614469, is_Male=False, is_infected=False, person_id=14, prob_hookup_hetero=0.8012729822, prob_hookup_homo=0.01727809628], Person [condom_budget=1.14156159442, is_Male=True, is_infected=False, person_id=15, prob_hookup_hetero=0.0331202987287, prob_hookup_homo=0.272986695718], Person [condom_budget=0.496586161879, is_Male=False, is_infected=False, person_id=16, prob_hookup_hetero=0.950665050836, prob_hookup_homo=0.254269768666], Person [condom_budget=0.820078436872, is_Male=True, is_infected=False, person_id=17, prob_hookup_hetero=0.839084338754, prob_hookup_homo=0.00810184778552], Person [condom_budget=1.99697610636, is_Male=False, is_infected=False, person_id=18, prob_hookup_hetero=0.779394730562, prob_hookup_homo=0.147628733998], Person [condom_budget=0.617472498696, is_Male=True, is_infected=False, person_id=19, prob_hookup_hetero=0.353159875571, prob_hookup_homo=0.2992357921], Person [condom_budget=1.10752232286, is_Male=False, is_infected=False, person_id=20, prob_hookup_hetero=0.0376524314183, prob_hookup_homo=0.104625151818], Person [condom_budget=0.103617404422, is_Male=True, is_infected=False, person_id=21, prob_hookup_hetero=0.157749670969, prob_hookup_homo=0.0531172882006], Person [condom_budget=1.65437770555, is_Male=True, is_infected=False, person_id=22, prob_hookup_hetero=0.184677875453, prob_hookup_homo=0.279257688647], Person [condom_budget=0.461338121527, is_Male=True, is_infected=False, person_id=23, prob_hookup_hetero=0.570378051049, prob_hookup_homo=0.0798554725522], Person [condom_budget=0.62531945429, is_Male=True, is_infected=False, person_id=24, prob_hookup_hetero=0.406578467289, prob_hookup_homo=0.125520913142]],
#
#
#
# 	people_sexlist=[[0, False], [1, False], [2, True], [3, True], [4, True], [5, True], [6, False], [7, True], [8, True], [9, True], [10, True], [11, True], [12, False], [13, True], [14, False], [15, True], [16, False], [17, True], [18, False], [19, True], [20, False], [21, True], [22, True], [23, True], [24, True]],
#
# prob_transmit_condom_hetero=0.1, prob_transmit_condom_homo_f=0.05, prob_transmit_condom_homo_m=0.2, prob_transmit_hetero=0.7, prob_transmit_homo_f=0.6, prob_transmit_homo_m=0.9,
#
# 	space=
# [[ nan  nan  nan  14.  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan   3.  nan  nan]
#  [ nan  nan  nan  nan   2.  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  15.  nan  nan  nan  nan  nan  nan  nan  nan  nan  11.  nan
#    nan  nan  nan  nan  nan  18.]
#  [ nan  nan  nan  23.  nan  nan  10.  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan   9.  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#     0.  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan   6.  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  13.  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  16.  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  17.  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan   8.  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan   7.  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  19.  22.  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan   4.  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  20.  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  12.  nan   1.  nan  nan  nan
#    nan  nan  nan  nan  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  24.  nan  nan  nan  nan  nan
#    nan  nan  nan   5.  nan  nan]
#  [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#    nan  nan  nan  21.  nan  nan]],
#
# t=0]

# %%
# Step over the model for a few steps
for i in xrange(1000):
    # Step
    m.step()
    
    # Update every 100 steps
    if i % 100 == 0:
        print((m.t, m.get_num_infected(), m.num_interactions, m.num_interactions_condoms))
# Out:
# (1, 1, 1, 1)
# (101, 1, 103, 88)
# (201, 4, 170, 145)
# (301, 12, 259, 213)
# (401, 16, 373, 297)
# (501, 20, 477, 389)
# (601, 22, 554, 449)
# (701, 25, 687, 566)
# (801, 25, 795, 663)
# (901, 25, 889, 746)

# %%
# Plot time series.
f = plt.figure()
plt.subplot(211)
plt.plot(m.history_num_infected)
plt.legend(("Number of infections"), loc="best")
plt.subplot(212)
plt.plot(numpy.array(m.history_num_interactions) - numpy.array(m.history_num_interactions_condoms))
plt.plot(m.history_num_interactions_condoms)
plt.legend(("Number of interactions without condoms",
           "Number of interactions with condoms"),
          loc="best")

# %%
from IPython.html.widgets.widget_int import *
# Get colormap
cmap = seaborn.cubehelix_palette(light=1, as_cmap=True)

def plot_space_infected(t=None):
        """
        Return a projection of the space that shows which cells have an infected person.
        """
        f = plt.figure()
        plt.title("Infected space at t={0}".format(t))
        plt.pcolor(m.get_space_infected(t), vmin=-1, vmax=1, cmap=cmap)
        ax = f.gca()
        ax.set_aspect(1./ax.get_data_ratio())   
        plt.colorbar()
        
interact(plot_space_infected,
                t=IntSliderWidget(min=1, max=m.t-1, step=1))
# Out:
# <function __main__.plot_space_infected>

# %%
# Get the network of infections
edge_weight = {}
edge_color = {}

# Iterate over all interactions
for e in m.history_interactions:
    # Check if we have recorded this pair before.
    if (e[1], e[2]) not in edge_weight:
        edge_weight[(e[1], e[2])] = 1
        
        if e[-1] == True:
            edge_color[(e[1], e[2])] = "red"
        else:
            edge_color[(e[1], e[2])] = "#dddddd"
    else:
        edge_weight[(e[1], e[2])] += 1
        
        if e[-1] == True:
            edge_color[(e[1], e[2])] = "red"
        else:
            edge_color[(e[1], e[2])] = "#dddddd"

# %%
# Create graph
g = networkx.Graph()
g.add_nodes_from(range(m.num_people))
g.add_edges_from(edge_weight.keys())
g_layout = networkx.spring_layout(g, iterations=100)

# Get node info
healthy_nodes = [i for i in range(m.num_people) if not m.people[i].is_infected]
infected_nodes = [i for i in range(m.num_people) if m.people[i].is_infected]

# Now we can visualize the infection network.
f = plt.figure(figsize=(16, 16))
ax = f.gca()
networkx.draw_networkx_nodes(g, g_layout,
                       nodelist=infected_nodes,
                       node_size=25,
                       node_color='#b92732')

networkx.draw_networkx_nodes(g, g_layout,
                       node_size=25,
                       nodelist=healthy_nodes,
                       node_color='#64a171')

networkx.draw_networkx_edges(g, g_layout, 
                       width=1, 
                       alpha=0.5,
                       edge_cmap=cmap,
                       edge_color=edge_weight.values())

ax.grid(False)
ax.set_axis_bgcolor("#333333")

# %%
print('Total interactions are {0}'.format(m.num_interactions))
print('Total interactions with condoms are {0}'.format(m.num_interactions_condoms))
print('Transmissions by hetero_sex are {0}'.format(m.num_transmit_hetero))
print('Transmissions by female homo_sex are {0}'.format(m.num_transmit_homo_f))
print('Transmissions by male homo_sex are {0}'.format(m.num_transmit_homo_m))
# Out:
# Total interactions are 987
# Total interactions with condoms are 833
# Transmissions by hetero_sex are 20
# Transmissions by female homo_sex are 0
# Transmissions by male homo_sex are 4
